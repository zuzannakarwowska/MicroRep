# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from functools import partial
import torch
from torch import nn
import torch.nn.functional as F
from typing import Optional, Tuple
import torch.optim as optim
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from torch.utils.data import TensorDataset
from scipy.spatial.distance import pdist, squareform
from skbio.stats.ordination import pcoa    
from ray import tune
from ray.tune import CLIReporter
from ray.tune.schedulers import ASHAScheduler
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error
from torchmetrics.regression import MeanSquaredError, MeanAbsolutePercentageError
#https://medium.com/intel-student-ambassadors/implementing-attention-models-in-pytorch-f947034b3e66from ray import train
from ray import train, tune
from ray.tune import ResultGrid
import pandas as pd
import skbio
from skbio import TreeNode
from io import StringIO
from ete3 import Tree
from skbio import diversity 
from skbio.diversity.beta import unweighted_unifrac, weighted_unifrac
from scipy.spatial.distance import braycurtis
import warnings
from collections import Counter
import concurrent.futures

from scipy.spatial import procrustes
warnings.filterwarnings("ignore")

# %%
#https://towardsdatascience.com/regularisation-techniques-neural-networks-101-1f746ad45b72

# %%
torch.cuda.empty_cache()

# %% [markdown]
# communities = pd.read_csv('input_data/communities.csv')
# enterosignatures = pd.read_csv('input_data/NMF_genus.csv', index_col = [0])
# enterosignatures['dominant_ES'] = [enterosignatures.iloc[i].sort_values().index[-1] for i in range(len(enterosignatures))]
# wu_M = pd.read_csv('wu_m.csv', index_col = [0])

# %%
pathways = pd.read_csv('input_data/controls_pathways.csv', index_col= [0]).iloc[:, 2:].sort_index()
taxonomy = pd.read_csv('input_data/controls_taxonomy.csv', index_col= [0]).sort_index()
metadata = pd.read_csv('input_data/controls_metadata.csv', index_col= [0]).sort_index()

#metadata = metadata[metadata['age_category'] == 'adult']

# %%
def filter_prevalence(df, treshold = 0.05):
    '''features as columns'''
    df_binary = df.copy()
    df_binary[df_binary>0]=1
    df_binary_sum = df_binary.sum(axis=0)
    
    keep_features = df_binary_sum[df_binary_sum > df.shape[0]*treshold].index
    filtered_df = df[keep_features]
    
    return filtered_df

def filter_on_abundance(df, abundance_treshold = 1e-3):
    '''features as columns'''
    df_relab = df.div(df.sum(axis=1), axis=0)
    df_relab_mean = df_relab.mean()

    keep_features = df_relab_mean[df_relab_mean > abundance_treshold].index
    filtered_df = df[keep_features]
    
    return filtered_df


pathways = filter_on_abundance(filter_prevalence(pathways, 0.1))
taxonomy = filter_on_abundance(filter_prevalence(taxonomy, 0.1))

# %%
pathways = pathways.rank(axis=1, method='dense')
taxonomy = taxonomy.rank(axis=1, method='dense')

# %%
HMP_samples = metadata[metadata.study_name == 'HMP_2019_ibdmdb'].sample_id.values

HMP_pathways = pathways.loc[HMP_samples]
HMP_taxonomy = taxonomy.loc[HMP_samples]

#HMP_taxonomy_relab = HMP_taxonomy.div(HMP_taxonomy.sum(axis=1), axis=0).fillna(0)
#HMP_pathways_relab = HMP_pathways.div(HMP_pathways.sum(axis=1), axis=0).fillna(0)

# %%
other_samples = metadata[metadata.study_name != 'HMP_2019_ibdmdb'].sample_id.values

other_pathways = pathways.loc[other_samples]
other_taxonomy = taxonomy.loc[other_samples]

taxonomy_relab = other_taxonomy.div(other_taxonomy.sum(axis=1), axis=0).fillna(0)
pathways_relab = other_pathways.div(other_pathways.sum(axis=1), axis=0).fillna(0)

# %%
taxonomy_input = taxonomy.sample(5000, random_state=42).copy()
pathways_input = pathways.sample(5000, random_state=42).copy()

# %%
taxonomy_input.shape, pathways_input.shape
# Out:
# ((5000, 106), (5000, 204))

# %%
def apply_mask(input_data, mask_prob):
    mask = (torch.rand_like(input_data) > mask_prob).float()
    masked_input = input_data * mask
    return masked_input, mask

# %%
class VanillaAE(nn.Module):
    def __init__(self, input_dim1, input_dim2, hl1=64, hl2=32, feature_dim=16):
        super(VanillaAE, self).__init__()

        self.hl1 = hl1
        self.hl2 = hl2
        self.feature_dim = feature_dim

        # Initial encoders for both inputs
        self.encoder_first_part1 = nn.Sequential(nn.Linear(input_dim1, hl1), nn.ReLU())
        self.encoder_first_part2 = nn.Sequential(nn.Linear(input_dim2, hl1), nn.ReLU())

        # Shared encoder part after concatenating features
        self.encoder_second_part = nn.Sequential(
            nn.Linear(hl1 * 2, hl2),  # Features from both inputs
            nn.ReLU(),
            nn.Linear(hl2, feature_dim),
        )

        # Decoders
        self.decoder1 = nn.Sequential(nn.Linear(feature_dim, hl2), nn.ReLU(), nn.Linear(hl2, hl1), nn.ReLU(), nn.Linear(hl1, input_dim1))
        self.decoder2 = nn.Sequential(nn.Linear(feature_dim, hl2), nn.ReLU(), nn.Linear(hl2, hl1), nn.ReLU(), nn.Linear(hl1, input_dim2))
        self.double()
        
    def forward(self, x1, x2, add_noise=False, noise_factor=0.1):
        x1_encoded = self.encoder_first_part1(x1)
        x2_encoded = self.encoder_first_part2(x2)

        concatenated_features = torch.cat((x1_encoded, x2_encoded), dim=1)
        
        # Pass through the shared encoder
        encoded = self.encoder_second_part(concatenated_features)

        # Decode
        reconstructed1 = self.decoder1(encoded)
        reconstructed2 = self.decoder2(encoded)

        return reconstructed1, reconstructed2

# %%
def prepare_data(df, test_size=0.2, random_state=42, scale=True):

    train_df, test_df = train_test_split(df, test_size=test_size, random_state=random_state)

    if scale == True:
        
        scaler = StandardScaler()
        X_train = scaler.fit_transform(train_df)
        X_test = scaler.transform(test_df)
    
    elif scale == False:
        X_train = train_df.copy()
        X_test = test_df.copy()
    
    train_tensor = torch.tensor(X_train, dtype=torch.float64)
    test_tensor = torch.tensor(X_test, dtype=torch.float64)
    
    train_dataset = torch.utils.data.TensorDataset(train_tensor, train_tensor)  
    test_dataset = torch.utils.data.TensorDataset(test_tensor, test_tensor)

    if scale == True:
        
        return scaler, train_dataset, test_dataset
    
    if scale == False:
        
        return [], train_dataset, test_dataset

# %%
def train_ae(config):
    
    checkpoint_dir = '.'
    model = VanillaAE(input_dim1=taxonomy_input.shape[1], 
                                 input_dim2=pathways_input.shape[1],
                                 hl1=config["hl1"], 
                                 hl2=config['hl2'], 
                                 feature_dim=config["feature_dim"])

    device = "cpu"
    if torch.cuda.is_available():
        device = "cuda:0"
        if torch.cuda.device_count() > 1:
            model = nn.DataParallel(model)
            
    model.to(device)
    
    # Assuming the reconstruction loss for both outputs is important
    criterion = nn.MSELoss() 
    optimizer = torch.optim.Adam(model.parameters(), lr=config['lr'])
    metric = MeanSquaredError()
    
    _, taxonomy_train_dataset, taxonomy_test_dataset = prepare_data(taxonomy_input)
    _, pathways_train_dataset, pathways_test_dataset = prepare_data(pathways_input)

    taxonomy_train_loader = torch.utils.data.DataLoader(taxonomy_train_dataset, batch_size=config['batch_size'], shuffle=True)
    taxonomy_test_loader = torch.utils.data.DataLoader(taxonomy_test_dataset, batch_size=config['batch_size'], shuffle=False)
    
    pathways_train_loader = torch.utils.data.DataLoader(pathways_train_dataset, batch_size=config['batch_size'], shuffle=True)
    pathways_test_loader = torch.utils.data.DataLoader(pathways_test_dataset, batch_size=config['batch_size'], shuffle=False)
    
    
    for epoch in range(100):
        
        model.train()
        running_loss = 0.0
        epoch_steps = 0.0
        t_MSE = 0.0
        p_MSE = 0.0
        
        for (t_data, t_target), (p_data, p_target)  in zip(taxonomy_train_loader, pathways_train_loader):
            
            t_data, t_target = t_data.to(device), t_target.to(device)
            p_data, p_target = p_data.to(device), p_target.to(p_target)
        
            masked_input1, mask1 = apply_mask(t_data, 0.15)
            masked_input2, mask2 = apply_mask(p_data, 0.15)
        
            optimizer.zero_grad()
        
            output1, output2 = model(masked_input1, masked_input2, add_noise=False)
            
            taxonomy_mse = metric(output1, t_target)
            pathways_mse = metric(output2, p_target)
            
            loss = criterion(output1, t_target) + criterion(output2, p_target)
            
            loss.backward()
            optimizer.step()
                
            running_loss += loss.item()
            t_MSE += taxonomy_mse.item()
            p_MSE += pathways_mse.item()
            epoch_steps += 1
            
            
        
        model.eval()
        test_loss = 0.0 
        test_steps = 0.0
        test_t_MSE = 0.0
        test_p_MSE = 0.0
        with torch.no_grad():
            
            for (t_data, t_target), (p_data, p_target)  in zip(taxonomy_test_loader, pathways_test_loader):
            
                dt_data, t_target = t_data.to(device), t_target.to(device)
                p_data, p_target = p_data.to(device), p_target.to(p_target)
            
                masked_input1, mask1 = apply_mask(t_data, 0.15)
                masked_input2, mask2 = apply_mask(p_data, 0.15)
                    
                output1, output2 = model(masked_input1, masked_input2, add_noise=False)

                taxonomy_mse = metric(output1, t_target)
                pathways_mse = metric(output2, p_target)
            
                loss = criterion(output1, t_target) + criterion(output2, p_target)
                
                test_loss += loss.item()
                test_t_MSE += taxonomy_mse.item()
                test_p_MSE += pathways_mse.item()
                test_steps += 1
                
        train.report({'loss':running_loss/epoch_steps, 
                      't_mse':t_MSE/epoch_steps,
                      'p_mse':p_MSE/epoch_steps,
                      'test_loss':test_loss/test_steps,
                     'test_t_mse':test_t_MSE/test_steps,
                      'test_p_mse':test_p_MSE/test_steps})
            
        print("Finished Training")

# %%
config = {
    "hl1": tune.choice([128, 64, 32, 16]),
    "hl2": tune.choice([128, 64, 32, 16]),
    "feature_dim": tune.choice([32, 16, 8, 4]),
    "lr": tune.loguniform(1e-4, 1e-1),
    "batch_size": tune.choice([8, 16, 32, 64, 128])}

scheduler = ASHAScheduler(
    max_t=50,
    grace_period=10,
    reduction_factor=2,
    )

tuner = tune.Tuner(
    train_ae,
    param_space=config,
    run_config=train.RunConfig(
        name='test',
        stop={"training_iteration": 50},
        checkpoint_config=train.CheckpointConfig(
            checkpoint_score_attribute="loss",
            num_to_keep=5,
        ),
        storage_path=None,
    ),
    tune_config=tune.TuneConfig(mode="min", metric="test_loss", num_samples=50, scheduler=scheduler),
)
result_grid: ResultGrid = tuner.fit()
# Out:
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2024-05-02 11:14:05</td></tr>
# <tr><td>Running for: </td><td>00:11:57.05        </td></tr>
# <tr><td>Memory:      </td><td>15.4/32.0 GiB      </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using AsyncHyperBand: num_stopped=39<br>Bracket: Iter 40.000: -0.7811980218014347 | Iter 20.000: -0.9107141302928954 | Iter 10.000: -1.0894054243035693<br>Logical resource usage: 1.0/16 CPUs, 0/0 GPUs
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name          </th><th>status    </th><th>loc            </th><th style="text-align: right;">  batch_size</th><th style="text-align: right;">  feature_dim</th><th style="text-align: right;">  hl1</th><th style="text-align: right;">  hl2</th><th style="text-align: right;">         lr</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">    loss</th><th style="text-align: right;">   t_mse</th><th style="text-align: right;">   p_mse</th></tr>
# </thead>
# <tbody>
# <tr><td>train_ae_a7944_00000</td><td>TERMINATED</td><td>127.0.0.1:23189</td><td style="text-align: right;">          64</td><td style="text-align: right;">           16</td><td style="text-align: right;">   32</td><td style="text-align: right;">   32</td><td style="text-align: right;">0.000467701</td><td style="text-align: right;">    20</td><td style="text-align: right;">         38.4033</td><td style="text-align: right;">0.917587</td><td style="text-align: right;">0.584184</td><td style="text-align: right;">0.333402</td></tr>
# <tr><td>train_ae_a7944_00001</td><td>TERMINATED</td><td>127.0.0.1:23190</td><td style="text-align: right;">           8</td><td style="text-align: right;">            8</td><td style="text-align: right;">   32</td><td style="text-align: right;">   16</td><td style="text-align: right;">0.000722233</td><td style="text-align: right;">    40</td><td style="text-align: right;">        489.696 </td><td style="text-align: right;">0.866991</td><td style="text-align: right;">0.586043</td><td style="text-align: right;">0.280948</td></tr>
# <tr><td>train_ae_a7944_00002</td><td>TERMINATED</td><td>127.0.0.1:23191</td><td style="text-align: right;">         128</td><td style="text-align: right;">           16</td><td style="text-align: right;">   16</td><td style="text-align: right;">  128</td><td style="text-align: right;">0.00304261 </td><td style="text-align: right;">    50</td><td style="text-align: right;">         63.6687</td><td style="text-align: right;">0.792224</td><td style="text-align: right;">0.526816</td><td style="text-align: right;">0.265408</td></tr>
# <tr><td>train_ae_a7944_00003</td><td>TERMINATED</td><td>127.0.0.1:23192</td><td style="text-align: right;">          32</td><td style="text-align: right;">            4</td><td style="text-align: right;">   64</td><td style="text-align: right;">   16</td><td style="text-align: right;">0.00217147 </td><td style="text-align: right;">    10</td><td style="text-align: right;">         31.9088</td><td style="text-align: right;">1.06646 </td><td style="text-align: right;">0.720966</td><td style="text-align: right;">0.345494</td></tr>
# <tr><td>train_ae_a7944_00004</td><td>TERMINATED</td><td>127.0.0.1:23193</td><td style="text-align: right;">           8</td><td style="text-align: right;">            4</td><td style="text-align: right;">  128</td><td style="text-align: right;">   64</td><td style="text-align: right;">0.00190104 </td><td style="text-align: right;">    20</td><td style="text-align: right;">        231.291 </td><td style="text-align: right;">1.00346 </td><td style="text-align: right;">0.661867</td><td style="text-align: right;">0.341592</td></tr>
# <tr><td>train_ae_a7944_00005</td><td>TERMINATED</td><td>127.0.0.1:23194</td><td style="text-align: right;">           8</td><td style="text-align: right;">           32</td><td style="text-align: right;">   64</td><td style="text-align: right;">   64</td><td style="text-align: right;">0.00081668 </td><td style="text-align: right;">    50</td><td style="text-align: right;">        589.345 </td><td style="text-align: right;">0.582316</td><td style="text-align: right;">0.395608</td><td style="text-align: right;">0.186708</td></tr>
# <tr><td>train_ae_a7944_00006</td><td>TERMINATED</td><td>127.0.0.1:23195</td><td style="text-align: right;">           8</td><td style="text-align: right;">            4</td><td style="text-align: right;">   16</td><td style="text-align: right;">   32</td><td style="text-align: right;">0.00766472 </td><td style="text-align: right;">    10</td><td style="text-align: right;">         95.2895</td><td style="text-align: right;">1.11949 </td><td style="text-align: right;">0.733103</td><td style="text-align: right;">0.386391</td></tr>
# <tr><td>train_ae_a7944_00007</td><td>TERMINATED</td><td>127.0.0.1:23196</td><td style="text-align: right;">          16</td><td style="text-align: right;">            4</td><td style="text-align: right;">   64</td><td style="text-align: right;">   32</td><td style="text-align: right;">0.000187972</td><td style="text-align: right;">    10</td><td style="text-align: right;">         55.8685</td><td style="text-align: right;">1.15832 </td><td style="text-align: right;">0.746714</td><td style="text-align: right;">0.411609</td></tr>
# <tr><td>train_ae_a7944_00008</td><td>TERMINATED</td><td>127.0.0.1:23197</td><td style="text-align: right;">          32</td><td style="text-align: right;">           32</td><td style="text-align: right;">   16</td><td style="text-align: right;">   32</td><td style="text-align: right;">0.0222084  </td><td style="text-align: right;">    10</td><td style="text-align: right;">         29.7854</td><td style="text-align: right;">1.44035 </td><td style="text-align: right;">0.766556</td><td style="text-align: right;">0.673797</td></tr>
# <tr><td>train_ae_a7944_00009</td><td>TERMINATED</td><td>127.0.0.1:23198</td><td style="text-align: right;">          64</td><td style="text-align: right;">            8</td><td style="text-align: right;">   16</td><td style="text-align: right;">   16</td><td style="text-align: right;">0.0409898  </td><td style="text-align: right;">    10</td><td style="text-align: right;">         18.3495</td><td style="text-align: right;">1.29689 </td><td style="text-align: right;">0.758044</td><td style="text-align: right;">0.538844</td></tr>
# <tr><td>train_ae_a7944_00010</td><td>TERMINATED</td><td>127.0.0.1:23199</td><td style="text-align: right;">          32</td><td style="text-align: right;">            4</td><td style="text-align: right;">  128</td><td style="text-align: right;">   16</td><td style="text-align: right;">0.000279136</td><td style="text-align: right;">    10</td><td style="text-align: right;">         35.1498</td><td style="text-align: right;">1.12013 </td><td style="text-align: right;">0.685552</td><td style="text-align: right;">0.434581</td></tr>
# <tr><td>train_ae_a7944_00011</td><td>TERMINATED</td><td>127.0.0.1:23200</td><td style="text-align: right;">           8</td><td style="text-align: right;">           32</td><td style="text-align: right;">   64</td><td style="text-align: right;">   16</td><td style="text-align: right;">0.00173305 </td><td style="text-align: right;">    50</td><td style="text-align: right;">        583.031 </td><td style="text-align: right;">0.727788</td><td style="text-align: right;">0.504265</td><td style="text-align: right;">0.223524</td></tr>
# <tr><td>train_ae_a7944_00012</td><td>TERMINATED</td><td>127.0.0.1:23201</td><td style="text-align: right;">           8</td><td style="text-align: right;">            8</td><td style="text-align: right;">   64</td><td style="t
# (raylet) Warning: The actor ImplicitFunc is very large (24 MiB). Check that its definition is not implicitly capturing a large array or other object in scope. Tip: use ray.put() to put large objects in the Ray object store.
# (train_ae pid=23191) Finished Training
# (train_ae pid=23189) Finished Training [repeated 22x across cluster]
# (train_ae pid=23191) Finished Training [repeated 32x across cluster]
# (train_ae pid=23195) Finished Training [repeated 22x across cluster]
# (train_ae pid=23203) Finished Training [repeated 24x across cluster]
# (train_ae pid=23190) Finished Training [repeated 15x across cluster]
# (train_ae pid=23189) Finished Training [repeated 14x across cluster]
# (train_ae pid=23190) Finished Training [repeated 8x across cluster]
# (train_ae pid=23191) Finished Training [repeated 9x across cluster]
# (train_ae pid=23202) Finished Training [repeated 10x across cluster]
# (train_ae pid=23202) Finished Training [repeated 12x across cluster]
# (train_ae pid=23191) Finished Training [repeated 12x across cluster]
# (train_ae pid=23236) Finished Training [repeated 11x across cluster]
# (train_ae pid=23236) Finished Training [repeated 21x across cluster]
# (train_ae pid=23234) Finished Training [repeated 19x across cluster]
# (train_ae pid=23202) Finished Training [repeated 17x across cluster]
# (train_ae pid=23202) Finished Training [repeated 10x across cluster]
# (train_ae pid=23256) Finished Training [repeated 14x across cluster]
# (train_ae pid=23202) Finished Training [repeated 11x across cluster]
# (train_ae pid=23256) Finished Training [repeated 13x across cluster]
# (train_ae pid=23256) Finished Training [repeated 9x across cluster]
# (train_ae pid=23256) Finished Training [repeated 15x across cluster]
# (train_ae pid=23229) Finished Training [repeated 14x across cluster]
# (train_ae pid=23233) Finished Training [repeated 15x across cluster]
# (train_ae pid=23190) Finished Training [repeated 11x across cluster]
# (train_ae pid=23256) Finished Training [repeated 15x across cluster]
# (train_ae pid=23293) Finished Training [repeated 18x across cluster]
# (train_ae pid=23256) Finished Training [repeated 18x across cluster]
# (train_ae pid=23292) Finished Training [repeated 18x across cluster]
# (train_ae pid=23292) Finished Training [repeated 12x across cluster]
# (train_ae pid=23288) Finished Training [repeated 12x across cluster]
# (train_ae pid=23190) Finished Training [repeated 17x across cluster]
# (train_ae pid=23233) Finished Training [repeated 14x across cluster]
# (train_ae pid=23292) Finished Training [repeated 15x across cluster]
# (train_ae pid=23288) Finished Training [repeated 17x across cluster]
# (train_ae pid=23298) Finished Training [repeated 14x across cluster]
# (train_ae pid=23292) Finished Training [repeated 17x across cluster]
# (train_ae pid=23292) Finished Training [repeated 18x across cluster]
# (train_ae pid=23190) Finished Training [repeated 17x across cluster]
# (train_ae pid=23297) Finished Training [repeated 16x across cluster]
# (train_ae pid=23285) Finished Training [repeated 19x across cluster]
# (train_ae pid=23312) Finished Training [repeated 16x across cluster]
# (train_ae pid=23315) Finished Training [repeated 13x across cluster]
# (train_ae pid=23298) Finished Training [repeated 16x across cluster]
# (train_ae pid=23312) Finished Training [repeated 10x across cluster]
# (train_ae pid=23264) Finished Training [repeated 9x across cluster]
# (train_ae pid=23309) Finished Training [repeated 7x across cluster]
# (train_ae pid=23264) Finished Training [repeated 9x across cluster]
# (train_ae pid=23309) Finished Training [repeated 6x across cluster]
# (train_ae pid=23298) Finished Training [repeated 7x across cluster]
# (train_ae pid=23309) Finished Training [repeated 7x across cluster]
# (train_ae pid=23298) Finished Training [repeated 8x across cluster]
# (train_ae pid=23297) Finished Training [repeated 8x across cluster]
# (train_ae pid=23297) Finished Training [repeated 6x across cluster]
# (train_ae pid=23297) Finished Training [repeated 11x across cluster]
# (train_ae pid=23354) Finished Training [repeated 4x across cluster]
# (train_ae pid=23308) Finished Training [repeated 8x across cluster]
# (train_ae pid=23362) Finished Training [repeated 6x across cluster]
# (train_ae pid=23264) Finished Training [repeated 8x across cluster]
# (train_ae pid=23359) Finished Training [repeated 6x across cluster]
# (train_ae pid=23395) Finished Training [repeated 4x across cluster]
# (train_ae pid=23359) Finished Training [repeated 6x across cluster]
# (train_ae pid=23264) Finished Training [repeated 8x across cluster]
# (train_ae pid=23359) Finished Training [repeated 4x across cluster]
# (train_ae pid=23264) Finished Training [repeated 7x across cluster]
# (train_ae pid=23359) Finished Training [repeated 7x across cluster]
# (train_ae pid=23415) Finished Training [repeated 9x across cluster]
# (train_ae pid=23359) Finished Training [repeated 7x across cluster]
# (train_ae pid=23426) Finished Training [repeated 8x across cluster]
# (train_ae pid=23359) Finished Training [repeated 8x across cluster]
# (train_ae pid=23395) Finished Training [repeated 8x across cluster]
# (train_ae pid=23415) Finished Training [repeated 4x across cluster]
# (train_ae pid=23264) Finished Training [repeated 7x across cluster]
# (train_ae pid=23285) Finished Training [repeated 4x across cluster]
# (train_ae pid=23309) Finished Training [repeated 8x across cluster]
# (train_ae pid=23412) Finished Training [repeated 3x across cluster]
# (train_ae pid=23190) Finished Training [repeated 3x across cluster]
# (train_ae pid=23309) Finished Training [repeated 9x across cluster]
# (train_ae pid=23264) Finished Training [repeated 3x across cluster]
# (train_ae pid=23412) Finished Training [repeated 7x across cluster]
# (train_ae pid=23309) Finished Training [repeated 6x across cluster]
# (train_ae pid=23415) Finished Training [repeated 4x across cluster]
# (train_ae pid=23415) Finished Training [repeated 7x across cluster]
# (train_ae pid=23309) Finished Training [repeated 4x across cluster]
# (train_ae pid=23194) Finished Training [repeated 5x across cluster]
# (train_ae pid=23415) Finished Training [repeated 5x across cluster]
# (train_ae pid=23264) Finished Training [repeated 2x across cluster]
# (train_ae pid=23194) Finished Training [repeated 6x across cluster]
# (train_ae pid=23309) Finished Training [repeated 5x across cluster]
# (train_ae pid=23415) Finished Training [repeated 2x across cluster]
# (train_ae pid=23285) Finished Training [repeated 7x across cluster]
# (train_ae pid=23309) Finished Training [repeated 3x across cluster]
# (train_ae pid=23194) Finished Training [repeated 4x across cluster]
# (train_ae pid=23309) Finished Training [repeated 3x across cluster]
# (train_ae pid=23309) Finished Training [repeated 4x across cluster]
# (train_ae pid=23194) Finished Training [repeated 5x across cluster]
# (train_ae pid=23285) Finished Training [repeated 3x across cluster]
# (train_ae pid=23200) Finished Training [repeated 5x across cluster]
# (train_ae pid=23200) Finished Training [repeated 5x across cluster]
# (train_ae pid=23200) Finished Training [repeated 6x across cluster]
# (train_ae pid=23285) Finished Training [repeated 6x across cluster]
# (train_ae pid=23285) Finished Training [repeated 5x across cluster]
# (train_ae pid=23475) Finished Training [repeated 5x across cluster]
# (train_ae pid=23475) Finished Training [repeated 5x across cluster]
# (train_ae pid=23285) Finished Training [repeated 3x across cluster]
# (train_ae pid=23475) Finished Training [repeated 4x across cluster]
# (train_ae pid=23475) Finished Training [repeated 4x across cluster]
# (train_ae pid=23285) Finished Training [repeated 3x across cluster]
# (train_ae pid=23475) Finished Training [repeated 4x across cluster]
# (train_ae pid=23285) Finished Training [repeated 5x across cluster]
# (train_ae pid=23285) Finished Training [repeated 5x across cluster]
# (train_ae pid=23285) Finished Training [repeated 4x across cluster]
# (train_ae pid=23475) Finished Training [repeated 4x across cluster]
# (train_ae pid=23475) Finished Training [repeated 5x across cluster]
# (train_ae pid=23475) Finished Training [repeated 3x across cluster]
# (train_ae pid=23475) Finished Training [repeated 2x across cluster]
# (train_ae pid=23475) Finished Training [repeated 2x across cluster]
# (train_ae pid=23475) Finished Training [repeated 2x across cluster]
# 2024-05-02 11:14:05,314	WARNING experiment_state.py:205 -- Experiment state snapshotting has been triggered multiple times in the last 5.0 seconds. A snapshot is forced if `CheckpointConfig(num_to_keep)` is set, and a trial has checkpointed >= `num_to_keep` times since the last snapshot.
# You may want to consider increasing the `CheckpointConfig(num_to_keep)` or decreasing the frequency of saving checkpoints.
# You can suppress this error by setting the environment variable TUNE_WARN_EXCESSIVE_EXPERIMENT_CHECKPOINT_SYNC_THRESHOLD_S to a smaller value than the current threshold (5.0).
# 2024-05-02 11:14:05,366	INFO tune.py:1004 -- Wrote the latest version of all result files and experiment state to '/Users/zkarwowska/ray_results/test' in 0.0739s.
# 2024-05-02 11:14:05,407	INFO tune.py:1036 -- Total run time: 717.20 seconds (716.97 seconds for the tuning loop).

# %%
best_checkpoint = result_grid.get_best_result(metric = 'test_loss')
best_params = best_checkpoint.config

# %%
best_checkpoint #NOW
# Out:
# Result(
#   metrics={'loss': 0.5823159440054537, 't_mse': 0.3956080932319164, 'p_mse': 0.18670785084366798, 'test_loss': 0.6076129748191238, 'test_t_mse': 0.41033144652843473, 'test_p_mse': 0.19728152960538864},
#   path='/Users/zkarwowska/ray_results/test/train_ae_a7944_00005_5_batch_size=8,feature_dim=32,hl1=64,hl2=64,lr=0.0008_2024-05-02_11-02-13',
#   filesystem='local',
#   checkpoint=None
# )

# %%
pathways_input.shape, taxonomy_input.shape
# Out:
# ((5000, 204), (5000, 106))

# %%
t_scaler, taxonomy_train_dataset, taxonomy_test_dataset = prepare_data(taxonomy_input)
p_scaler, pathways_train_dataset, pathways_test_dataset = prepare_data(pathways_input)

model = VanillaAE(input_dim1=taxonomy_input.shape[1], 
                       input_dim2=pathways_input.shape[1], 
                       hl1=best_params['hl1'], 
                       hl2=best_params['hl2'], 
                       feature_dim=best_params['feature_dim'])

device = "cpu"
if torch.cuda.is_available():
    device = "cuda:0"
    if torch.cuda.device_count() > 1:
        model = nn.DataParallel(model)
        
model.to(device)

criterion = nn.MSELoss()

optimizer = torch.optim.Adam(model.parameters(), lr=best_params['lr'])
metric = MeanAbsolutePercentageError()

batch_size = best_params['batch_size']
taxonomy_train_loader = torch.utils.data.DataLoader(taxonomy_train_dataset, batch_size=batch_size, shuffle=False)
taxonomy_test_loader = torch.utils.data.DataLoader(taxonomy_test_dataset, batch_size=batch_size, shuffle=False)

pathways_train_loader = torch.utils.data.DataLoader(pathways_train_dataset, batch_size=batch_size, shuffle=False)
pathways_test_loader = torch.utils.data.DataLoader(pathways_test_dataset, batch_size=batch_size, shuffle=False)

results = []
for epoch in range(400):

    model.train()
    running_loss = 0.0
    epoch_steps = 0.0
    t_MSE = 0.0
    p_MSE = 0.0
    
    for (t_data, t_target), (p_data, p_target) in zip(taxonomy_train_loader, pathways_train_loader):
        
        t_data, t_target = t_data.to(device), t_target.to(device)
        p_data, p_target = p_data.to(device), p_target.to(p_target)
    
        masked_input1, mask1 = apply_mask(t_data, 0.15)
        masked_input2, mask2 = apply_mask(p_data, 0.15)
    
        optimizer.zero_grad()
    
        output1, output2 = model(masked_input1, masked_input2, add_noise=True)
        
        loss = criterion(output1, t_target) +  criterion(output2, p_target)

        taxonomy_mse = metric(output1, t_target)
        pathways_mse = metric(output2, p_target)
        
        loss.backward()
        optimizer.step()
            
        running_loss += loss.item()
        t_MSE += taxonomy_mse.item()
        p_MSE += pathways_mse.item()
        epoch_steps += 1
        
            
    model.eval()
    test_loss = 0.0 
    test_steps = 0.0
    test_t_MSE = 0.0
    test_p_MSE = 0.0
    
    with torch.no_grad():
        
        for (t_data, t_target), (p_data, p_target) in zip(taxonomy_test_loader, pathways_test_loader):
        
            t_data, t_target = t_data.to(device), t_target.to(device)
            p_data, p_target = p_data.to(device), p_target.to(p_target)
        
            masked_input1, mask1 = apply_mask(t_data, 0.15)
            masked_input2, mask2 = apply_mask(p_data, 0.15)

            output1, output2 = model(masked_input1, masked_input2, add_noise=True)

            taxonomy_mse = metric(output1, t_target)
            pathways_mse = metric(output2, p_target)
        
            loss = criterion(output1, t_target) + criterion(output2, p_target)

            test_loss += loss.item()
            test_t_MSE += taxonomy_mse.item()
            test_p_MSE += pathways_mse.item()
            test_steps += 1
    
    results.append({'epoch':epoch,
                    'loss':running_loss/epoch_steps,
                    't_MSE':t_MSE/epoch_steps,
                    'p_MSE':p_MSE/epoch_steps,
                    'test_loss':test_loss/test_steps,
                    'test_t_MSE':test_t_MSE/test_steps,
                    'test_p_MSE':test_p_MSE/test_steps})

# %%
history = pd.DataFrame(results)

sns.lineplot(x = history.epoch, y = history.loss, color = 'k', label = 'train')
sns.lineplot(x = history.epoch, y = history.test_loss, color = 'orange', label = 'test')
plt.title('model training')
plt.tight_layout()
plt.savefig('plots/vanillaAE/ranks/history.png', dpi=300)

# %% [markdown]
# ### SHOW DATA ON VAL DATASET

# %%
taxonomy_val = HMP_taxonomy.copy() 
pathways_val = HMP_pathways.copy()

# %%
taxonomy_val_sc = t_scaler.transform(taxonomy_val)
taxonomy_val_sc_tensor = torch.tensor(taxonomy_val_sc, dtype=torch.float64)
taxonomy_val_masked, mask = apply_mask(taxonomy_val_sc_tensor, 0.15)

pathway_val_sc = p_scaler.transform(pathways_val)
pathway_val_sc_tensor = torch.tensor(pathway_val_sc, dtype=torch.float64)
pathway_val_masked, mask = apply_mask(pathway_val_sc_tensor, 0.15)

# %%
output1, output2 = model(taxonomy_val_masked, pathway_val_masked)

# %%
HMP_metadata = metadata[metadata.sample_id.isin(HMP_samples)]
subject_hue = HMP_metadata.subject_id.values

# %%
t_decoded = (t_scaler.inverse_transform(output1.detach().numpy()))
p_decoded = (p_scaler.inverse_transform(output2.detach().numpy()))

t_decoded[t_decoded<0]=0
p_decoded[p_decoded<0]=0

p_decoded_df = pd.DataFrame(p_decoded, columns = pathways_val.columns)
t_decoded_df = pd.DataFrame(t_decoded, columns = taxonomy_val.columns)

p_decoded_df.index = pathways_val.index
t_decoded_df.index = taxonomy_val.index

# %%
t_decoded_pcoa = pcoa(squareform(pdist((t_decoded_df), 'braycurtis'))).samples.iloc[:, :2]
t_true_pcoa = pcoa(squareform(pdist((taxonomy_val), 'braycurtis'))).samples.iloc[:, :2]
p_decoded_pcoa = pcoa(squareform(pdist((p_decoded_df), 'braycurtis'))).samples.iloc[:, :2]
p_true_pcoa = pcoa(squareform(pdist((pathways_val), 'braycurtis'))).samples.iloc[:, :2]

Tmtx1, Tmtx2, Tdisp = procrustes(t_decoded_pcoa, t_true_pcoa)
Pmtx1, Pmtx2, Pdisp = procrustes(p_decoded_pcoa, p_true_pcoa)

fig, axes = plt.subplots(1, 2, figsize = (10, 4))

sns.scatterplot(x = Tmtx2[:, 0], y = Tmtx2[:, 1], ax=axes[0], label = 'true')
sns.scatterplot(x = Tmtx1[:, 0], y = Tmtx1[:, 1], ax=axes[0], label = 'pred')

sns.scatterplot(x = Pmtx2[:, 0], y = Pmtx2[:, 1], ax=axes[1], label = 'true')
sns.scatterplot(x = Pmtx1[:, 0], y = Pmtx1[:, 1], ax=axes[1], label = 'pred')

axes[0].set_xlabel('C1')
axes[0].set_ylabel('C2')

axes[1].set_xlabel('C1')
axes[1].set_ylabel('C2')

plt.tight_layout()

axes[0].set_title(f'PROCURUSTES TAXONOMY disparity={np.round(Tdisp, 3)}')
axes[1].set_title(f'PROCURUSTES PATHWAYS disparity={np.round(Pdisp, 3)}')

plt.tight_layout()
plt.savefig('plots/vanillaAE/ranks/braycurtis_procrustes_taxonomy_pathways.png', dpi=300)

# %%
t_decoded_pcoa = pcoa(squareform(pdist(np.log(t_decoded_df+1e-2), 'euclidean'))).samples.iloc[:, :2]
t_true_pcoa = pcoa(squareform(pdist(np.log(taxonomy_val+1e-2), 'euclidean'))).samples.iloc[:, :2]
p_decoded_pcoa = pcoa(squareform(pdist(np.log(p_decoded_df+1e-2), 'euclidean'))).samples.iloc[:, :2]
p_true_pcoa = pcoa(squareform(pdist(np.log(pathways_val+1e-2), 'euclidean'))).samples.iloc[:, :2]

Tmtx1, Tmtx2, Tdisp = procrustes(t_decoded_pcoa, t_true_pcoa)
Pmtx1, Pmtx2, Pdisp = procrustes(p_decoded_pcoa, p_true_pcoa)

fig, axes = plt.subplots(1, 2, figsize = (10, 4))

sns.scatterplot(x = Tmtx2[:, 0], y = Tmtx2[:, 1], ax=axes[0], label = 'true')
sns.scatterplot(x = Tmtx1[:, 0], y = Tmtx1[:, 1], ax=axes[0], label = 'pred')

sns.scatterplot(x = Pmtx2[:, 0], y = Pmtx2[:, 1], ax=axes[1], label = 'true')
sns.scatterplot(x = Pmtx1[:, 0], y = Pmtx1[:, 1], ax=axes[1], label = 'pred')

axes[0].set_xlabel('C1')
axes[0].set_ylabel('C2')

axes[1].set_xlabel('C1')
axes[1].set_ylabel('C2')

plt.tight_layout()

axes[0].set_title(f'PROCURUSTES TAXONOMY disparity={np.round(Tdisp, 3)}')
axes[1].set_title(f'PROCURUSTES PATHWAYS disparity={np.round(Pdisp, 3)}')

plt.tight_layout()
plt.savefig('plots/vanillaAE/ranks/euclidean_procrustes_taxonomy_pathways.png', dpi=300)

# %%
decoded_df = pd.concat([t_decoded_df, p_decoded_df],axis=1)
decoded_relab = decoded_df.div(decoded_df.sum(axis=1), axis=0)
true_df = pd.concat([taxonomy_val, pathways_val],axis=1)
true_relab = true_df.div(true_df.sum(axis=1), axis=0)

decoded_pcoa = pcoa(squareform(pdist(np.log(decoded_relab+1e-2), 'euclidean'))).samples.iloc[:, :2]
true_pcoa = pcoa(squareform(pdist(np.log(true_relab+1e-2), 'euclidean'))).samples.iloc[:, :2]

A, B, disp = procrustes(true_pcoa, decoded_pcoa)

plt.figure(figsize = (10, 10))
sns.scatterplot(x = A[:, 0], y = A[:, 1], label = 'true', s=100)
sns.scatterplot(x = B[:, 0], y = B[:, 1], label = 'decoded', s=100)

for i in range(len(A)):
    plt.plot([A[i][0], B[i][0]], [A[i][1], B[i][1]], 'black', linestyle='-')  # Connect with dashed gray lines

plt.title(f'PROCURUSTES TAXONOMY + PATHWAYS disparity={np.round(disp, 3)}')
plt.tight_layout()
plt.savefig('plots/vanillaAE/ranks/procrustes.png', dpi=300)

# %%
fig, axes = plt.subplots(2, 3, figsize = (15, 10))

sns.scatterplot(x = t_true_pcoa.PC1, y=t_true_pcoa.PC2, hue = subject_hue, palette = 'Set1', s=60, ax=axes[0, 0], legend=False, edgecolor='k')
sns.scatterplot(x = p_true_pcoa.PC1, y=p_true_pcoa.PC2, hue = subject_hue, palette = 'Set1', s=60, ax=axes[0, 1], legend=False, edgecolor='k')
sns.scatterplot(x = true_pcoa.PC1, y=true_pcoa.PC2, hue = subject_hue, palette = 'Set1', s=60, ax=axes[0, 2], legend=False, edgecolor='k')

sns.scatterplot(x = t_decoded_pcoa.PC1, y=t_decoded_pcoa.PC2, hue = subject_hue, palette = 'Set1', s=50, ax=axes[1, 0], legend=False, edgecolor='k')
sns.scatterplot(x = p_decoded_pcoa.PC1, y=p_decoded_pcoa.PC2, hue = subject_hue, palette = 'Set1', s=50, ax=axes[1, 1], legend=False, edgecolor='k')
sns.scatterplot(x = decoded_pcoa.PC1, y=decoded_pcoa.PC2, hue = subject_hue, palette = 'Set1', s=60, ax=axes[1, 2], edgecolor='k')

axes[0, 0].set_ylabel(f'TRUE \n PC1')
axes[1, 0].set_ylabel(f'PRED \n PC1')

axes[0, 0].set_title(f'TAXONOMY')
axes[0, 1].set_title(f'PATHWAYS')
axes[0, 2].set_title(f'TAXONOMY + PATHWAYS')

plt.legend(bbox_to_anchor = (1.1, 1))
plt.tight_layout()
plt.savefig('plots/vanillaAE/ranks/pcoa.png', dpi=300)

# %% [markdown]
# ## LATENT

# %%
#HMP_data.subject_id.tolist()

# LATENT
l1 = model.encoder_first_part1(taxonomy_val_sc_tensor)
l2 = model.encoder_first_part2(pathway_val_sc_tensor)

concatenated_features = torch.cat((l1, l2), dim=1)
encoded = model.encoder_second_part(concatenated_features)

pcoa_df = pcoa(squareform(pdist(encoded.detach().numpy(), 'cosine'))).samples.iloc[:, :3]

plt.figure(figsize = (6, 6))
sns.scatterplot(x = pcoa_df['PC1'], y = pcoa_df['PC2'], hue = subject_hue.tolist(), legend=True, edgecolor='k', s=70,  palette = 'Set1')
plt.tight_layout()
plt.savefig('plots/vanillaAE/ranks/latent.png', dpi=300)

# %%
from sklearn.manifold import TSNE

tsne = TSNE()
tsne_embedding = tsne.fit_transform(encoded.detach().numpy())

plt.figure(figsize = (6, 6))
sns.scatterplot(x = tsne_embedding[:, 0], y = tsne_embedding[:, 1], hue = subject_hue.tolist(), legend=True, edgecolor='k', s=70,  palette = 'Set1')
plt.legend(bbox_to_anchor = (1.1, 1))
plt.tight_layout()
plt.savefig('plots/vanillaAE/ranks/latent_tsne.png', dpi=300)

# %%
pathways_val['data'] = 'true'
p_decoded_df['data'] = 'pred'

pathways_df = pd.concat([pathways_val, p_decoded_df], axis=0)
pathways_pcoa = pcoa(squareform(pdist(np.log(pathways_df.set_index('data')+1e-2), 'euclidean'))).samples

taxonomy_val['data'] = 'true'
t_decoded_df['data'] = 'pred'

taxonomy_df = pd.concat([taxonomy_val, t_decoded_df], axis=0)
taxonomy_pcoa = pcoa(squareform(pdist(np.log(taxonomy_df.set_index('data')+1e-2), 'euclidean'))).samples

fig, axes = plt.subplots(1, 2, figsize = (10, 5))
sns.scatterplot(x = pathways_pcoa.PC1, y=pathways_pcoa.PC2, hue = pathways_df.data.values, palette = 'Set1', s=50, legend=True, edgecolor='k', ax=axes[0])
sns.scatterplot(x = taxonomy_pcoa.PC1, y=taxonomy_pcoa.PC2, hue = pathways_df.data.values, palette = 'Set1', s=50, legend=True, edgecolor='k', ax=axes[1])

axes[0].set_title('PATHWAYS')
axes[1].set_title('TAXONOMY')

plt.savefig('plots/vanillaAE/ranks/euclidean_pathways.png', dpi=300)

# %%
# Prepare tree for unifrac analysis
nwk = 'input_data/tree.nwk'

ete3_tree = Tree(newick = nwk)
skbio_tree = TreeNode.read(nwk, 'newick')
leaf_names = ete3_tree.get_leaf_names()

otu_ids = taxonomy_input.columns.tolist()

#prune tree to only bacteria present in counts table
ete3_tree.prune(otu_ids, True)
pruned_skbio_tree = TreeNode.read(StringIO(ete3_tree.write(format=1, format_root_node=True)))

def replace_spaces_in_names_skbio(node):
    # Replace spaces with double underscores in the current node's name if it has one
    if node.name:
        node.name = node.name.replace(' ', '_')
    # Recursively apply this to all children
    for child in node.children:
        replace_spaces_in_names_skbio(child)

# Apply the function to your tree
replace_spaces_in_names_skbio(pruned_skbio_tree)

# %%
wUW_taxonomy = taxonomy_df.iloc[:, :-1]

# %%
import numpy as np
from joblib import Parallel, delayed

num_samples = wUW_taxonomy.shape[0]

# Function to calculate distance for one pair
def calculate_distance(i, j):
    if j > i:  # Ensures we calculate only for the upper triangle
        distance = weighted_unifrac(wUW_taxonomy.iloc[i], wUW_taxonomy.iloc[j], otu_ids, pruned_skbio_tree)
        return i, j, distance
    return i, j, 0

# Initialize an empty matrix to store the distances
distance_matrix = np.zeros((num_samples, num_samples))

# Parallel computation of distances
results = Parallel(n_jobs=-1, verbose=10)(delayed(calculate_distance)(i, j) for i in range(num_samples) for j in range(i, num_samples))

# Fill the distance matrix using results
for i, j, distance in results:
    distance_matrix[i, j] = distance
    if i != j:  # Mirror the distance since the matrix is symmetric
        distance_matrix[j, i] = distance

wu_M = pd.DataFrame(distance_matrix, columns = wUW_taxonomy.index)
wu_M.index =  wUW_taxonomy.index
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    3.5s
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed:    3.5s
# [Parallel(n_jobs=-1)]: Done  29 tasks      | elapsed:    3.6s
# [Parallel(n_jobs=-1)]: Done  40 tasks      | elapsed:    3.6s
# [Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed:    3.6s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.18195811533084727s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Done  66 tasks      | elapsed:    3.7s
# [Parallel(n_jobs=-1)]: Done  81 tasks      | elapsed:    3.7s
# [Parallel(n_jobs=-1)]: Done  96 tasks      | elapsed:    3.7s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.08933782577514648s.) Setting batch_size=4.
# [Parallel(n_jobs=-1)]: Done 130 tasks      | elapsed:    3.8s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.09219098091125488s.) Setting batch_size=8.
# [Parallel(n_jobs=-1)]: Done 168 tasks      | elapsed:    3.8s
# [Parallel(n_jobs=-1)]: Done 244 tasks      | elapsed:    3.9s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.09706497192382812s.) Setting batch_size=16.
# [Parallel(n_jobs=-1)]: Done 352 tasks      | elapsed:    4.0s
# [Parallel(n_jobs=-1)]: Done 520 tasks      | elapsed:    4.0s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.140974760055542s.) Setting batch_size=32.
# [Parallel(n_jobs=-1)]: Done 832 tasks      | elapsed:    4.2s
# [Parallel(n_jobs=-1)]: Done 1344 tasks      | elapsed:    4.3s
# [Parallel(n_jobs=-1)]: Done 2080 tasks      | elapsed:    4.5s
# [Parallel(n_jobs=-1)]: Done 2880 tasks      | elapsed:    4.8s
# [Parallel(n_jobs=-1)]: Done 3680 tasks      | elapsed:    5.1s
# [Parallel(n_jobs=-1)]: Done 4544 tasks      | elapsed:    5.3s
# [Parallel(n_jobs=-1)]: Done 5408 tasks      | elapsed:    5.6s
# [Parallel(n_jobs=-1)]: Done 6336 tasks      | elapsed:    5.8s
# [Parallel(n_jobs=-1)]: Done 7264 tasks      | elapsed:    6.1s
# [Parallel(n_jobs=-1)]: Done 8256 tasks      | elapsed:    6.4s
# [Parallel(n_jobs=-1)]: Done 9248 tasks      | elapsed:    6.7s
# [Parallel(n_jobs=-1)]: Done 10304 tasks      | elapsed:    7.0s
# [Parallel(n_jobs=-1)]: Done 11360 tasks      | elapsed:    7.3s
# [Parallel(n_jobs=-1)]: Done 12480 tasks      | elapsed:    7.6s
# [Parallel(n_jobs=-1)]: Done 13600 tasks      | elapsed:    8.0s
# [Parallel(n_jobs=-1)]: Done 14784 tasks      | elapsed:    8.4s
# [Parallel(n_jobs=-1)]: Done 15968 tasks      | elapsed:    8.7s
# [Parallel(n_jobs=-1)]: Done 17216 tasks      | elapsed:    9.1s
# [Parallel(n_jobs=-1)]: Done 18464 tasks      | elapsed:    9.5s
# [Parallel(n_jobs=-1)]: Done 19776 tasks      | elapsed:   10.0s
# [Parallel(n_jobs=-1)]: Done 21088 tasks      | elapsed:   10.4s
# [Parallel(n_jobs=-1)]: Done 22464 tasks      | elapsed:   10.8s
# [Parallel(n_jobs=-1)]: Done 23840 tasks      | elapsed:   11.3s
# [Parallel(n_jobs=-1)]: Done 25280 tasks      | elapsed:   11.8s
# [Parallel(n_jobs=-1)]: Done 26720 tasks      | elapsed:   12.3s
# [Parallel(n_jobs=-1)]: Done 28224 tasks      | elapsed:   12.8s
# [Parallel(n_jobs=-1)]: Done 29728 tasks      | elapsed:   13.4s
# [Parallel(n_jobs=-1)]: Done 31296 tasks      | elapsed:   13.9s
# [Parallel(n_jobs=-1)]: Done 32864 tasks      | elapsed:   14.4s
# [Parallel(n_jobs=-1)]: Done 34496 tasks      | elapsed:   15.0s
# [Parallel(n_jobs=-1)]: Done 36128 tasks      | elapsed:   15.7s
# [Parallel(n_jobs=-1)]: Done 37824 tasks      | elapsed:   16.4s
# [Parallel(n_jobs=-1)]: Done 39520 tasks      | elapsed:   17.0s
# [Parallel(n_jobs=-1)]: Done 41280 tasks      | elapsed:   17.9s
# [Parallel(n_jobs=-1)]: Done 43040 tasks      | elapsed:   18.6s
# [Parallel(n_jobs=-1)]: Done 44864 tasks      | elapsed:   19.3s
# [Parallel(n_jobs=-1)]: Done 46688 tasks      | elapsed:   20.2s
# [Parallel(n_jobs=-1)]: Done 48576 tasks      | elapsed:   20.9s
# [Parallel(n_jobs=-1)]: Done 50464 tasks      | elapsed:   21.7s
# [Parallel(n_jobs=-1)]: Done 52416 tasks      | elapsed:   22.5s
# [Parallel(n_jobs=-1)]: Done 54368 tasks      | elapsed:   23.4s
# [Parallel(n_jobs=-1)]: Done 56384 tasks      | elapsed:   24.5s
# [Parallel(n_jobs=-1)]: Done 58400 tasks      | elapsed:   25.4s
# [Parallel(n_jobs=-1)]: Done 60480 tasks      | elapsed:   26.6s
# [Parallel(n_jobs=-1)]: Done 62560 tasks      | elapsed:   27.5s
# [Parallel(n_jobs=-1)]: Done 64704 tasks      | elapsed:   28.6s
# [Parallel(n_jobs=-1)]: Done 66848 tasks      | elapsed:   29.8s
# [Parallel(n_jobs=-1)]: Done 69056 tasks      | elapsed:   31.0s
# [Parallel(n_jobs=-1)]: Done 71264 tasks      | elapsed:   32.0s
# [Parallel(n_jobs=-1)]: Done 73536 tasks      | elapsed:   33.2s
# [Parallel(n_jobs=-1)]: Done 75808 tasks      | elapsed:   34.2s
# [Parallel(n_jobs=-1)]: Done 78144 tasks      | elapsed:   35.6s
# [Parallel(n_jobs=-1)]: Done 80480 tasks      | elapsed:   36.8s
# [Parallel(n_jobs=-1)]: Done 82880 tasks      | elapsed:   38.1s
# [Parallel(n_jobs=-1)]: Done 85280 tasks      | elapsed:   39.3s
# [Parallel(n_jobs=-1)]: Done 87744 tasks      | elapsed:   40.5s
# [Parallel(n_jobs=-1)]: Done 90208 tasks      | elapsed:   41.7s
# [Parallel(n_jobs=-1)]: Done 92736 tasks      | elapsed:   42.9s
# [Parallel(n_jobs=-1)]: Done 95264 tasks      | elapsed:   44.3s
# [Parallel(n_jobs=-1)]: Done 97856 tasks      | elapsed:   45.7s
# [Parallel(n_jobs=-1)]: Done 100448 tasks      | elapsed:   47.0s
# [Parallel(n_jobs=-1)]: Done 103104 tasks      | elapsed:   48.4s
# [Parallel(n_jobs=-1)]: Done 105760 tasks      | elapsed:   49.7s
# [Parallel(n_jobs=-1)]: Done 108480 tasks      | elapsed:   51.2s
# [Parallel(n_jobs=-1)]: Done 111200 tasks      | elapsed:   52.7s
# [Parallel(n_jobs=-1)]: Done 113984 tasks      | elapsed:   54.3s
# [Parallel(n_jobs=-1)]: Done 116768 tasks      | elapsed:   56.1s
# [Parallel(n_jobs=-1)]: Done 119616 tasks      | elapsed:   57.8s
# [Parallel(n_jobs=-1)]: Done 122464 tasks      | elapsed:   59.4s
# [Parallel(n_jobs=-1)]: Done 125376 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 128288 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 131264 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 134240 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 137280 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 140320 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 143424 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 146528 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 149696 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 152864 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 156096 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 159328 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 162624 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 165920 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 169280 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 172640 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 176064 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 179488 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 182976 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 186464 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 190016 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 193568 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 197184 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 200800 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 204480 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 208160 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 211904 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 215648 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 219456 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done 223264 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done 227136 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done 231008 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done 234944 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done 238880 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done 242880 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done 246880 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done 250944 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done 255008 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done 259136 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done 263264 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done 267456 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done 271648 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done 275904 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done 280160 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done 284480 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done 288800 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done 293184 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done 297568 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done 302016 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done 306464 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done 310976 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done 315488 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done 320064 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=-1)]: Done 324640 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=-1)]: Done 329280 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=-1)]: Done 333920 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=-1)]: Done 338624 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=-1)]: Done 343328 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=-1)]: Done 348096 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done 352864 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done 357696 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done 362528 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done 363314 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done 363378 out of 363378 | elapsed:  3.0min finished

# %%
unifrac_pcoa = pcoa(wu_M).samples
sns.scatterplot(x = unifrac_pcoa.PC1, y=unifrac_pcoa.PC2, hue = taxonomy_df.data.values, palette = 'Set1', s=50, legend=True, edgecolor='k')
plt.savefig('plots/vanillaAE/ranks/unifrac_pcoa.png', dpi=300)

# %%
from scipy.spatial.distance import braycurtis, jaccard, cosine
from scipy import stats

# %%
p_decoded_df.index = pathways_val.index
t_decoded_df.index = taxonomy_val.index

subjects_pathways_scores = score_subjects(p_decoded_df, pathways_val, 'pathways')
subjects_taxonomy_scores = score_subjects(t_decoded_df, taxonomy_val, 'taxonomy')

subject_scores = pd.concat([subjects_pathways_scores, subjects_taxonomy_scores], axis=0).reset_index()
subject_scores.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[74], line 4
#       1 p_decoded_df.index = pathways_val.index
#       2 t_decoded_df.index = taxonomy_val.index
# ----> 4 subjects_pathways_scores = score_subjects(p_decoded_df, pathways_val, 'pathways')
#       5 subjects_taxonomy_scores = score_subjects(t_decoded_df, taxonomy_val, 'taxonomy')
#       7 subject_scores = pd.concat([subjects_pathways_scores, subjects_taxonomy_scores], axis=0).reset_index()
#
# NameError: name 'score_subjects' is not defined

# %%
fig, axes = plt.subplots(1, 3, figsize = (12, 3))

sns.boxplot(data = subject_scores, y = 'bc', x = 'feature', color = 'white', width = .5, fliersize=0, ax=axes[0])
sns.swarmplot(data = subject_scores, y = 'bc', x = 'feature', s=2, alpha = 1, color='k', ax=axes[0])

sns.boxplot(data = subject_scores, y = 'cosine', x = 'feature', color = 'white', width = .5, fliersize=0, ax=axes[1])
sns.swarmplot(data = subject_scores, y = 'cosine', x = 'feature', s=2, alpha = 1, color='k', ax=axes[1])

sns.boxplot(data = subject_scores, y = 'spearman', x = 'feature', color = 'white', width = .5, fliersize=0, ax=axes[2])
sns.swarmplot(data = subject_scores, y = 'spearman', x = 'feature', s=2, alpha = 1, color='k', ax=axes[2])

plt.tight_layout()
#plt.savefig(f'subject_scores.png', dpi=300)

# %%
fig, axes = plt.subplots(1, 3, figsize = (15, 5))

sns.regplot(x=subject_scores[subject_scores['feature'] == 'taxonomy'].spearman.values, y= subject_scores[subject_scores['feature'] == 'pathways'].spearman.values, 
            line_kws = {'color':'red'}, 
            scatter_kws = {'edgecolor':'k', 'color':'white'}, ax=axes[0])
sns.regplot(x=subject_scores[subject_scores['feature'] == 'taxonomy'].mape.values, y= subject_scores[subject_scores['feature'] == 'pathways'].mape.values, 
            line_kws = {'color':'red'}, 
            scatter_kws = {'edgecolor':'k', 'color':'white'}, ax=axes[1])
sns.regplot(x=subject_scores[subject_scores['feature'] == 'taxonomy'].bc.values, y= subject_scores[subject_scores['feature'] == 'pathways'].bc.values, 
            line_kws = {'color':'red'}, 
            scatter_kws = {'edgecolor':'k', 'color':'white'}, ax=axes[2])

for idx in range(3):

    axes[idx].set_xlabel('taxonomy score')
    axes[idx].set_ylabel('pathways score')

axes[0].set_title('SPEARMAN R')
axes[1].set_title('MAPE')
axes[2].set_title('BRAY CURTIS')

plt.tight_layout()
#plt.savefig(f'subject_scores2.png', dpi=300)

# %%
p_decoded_df = p_decoded_df.iloc[:, :-1]
p_decoded_df[p_decoded_df<0]=0
t_decoded_df = t_decoded_df.iloc[:, :-1]
t_decoded_df[t_decoded_df<0]=0

# %%
pathways_scores = score_features(p_decoded_df, pathways_val, 'pathways')
taxonomy_scores = score_features(t_decoded_df, taxonomy_val, 'taxonomy')

# %%
feature_scores_df = pd.concat([pathways_scores, taxonomy_scores], axis=0).reset_index()

fig, axes = plt.subplots(1, 2, figsize = (10, 3))

sns.boxplot(data=feature_scores_df, x = 'feature', y = 'bc', color = 'white' ,width = .5, ax=axes[0])
sns.swarmplot(data=feature_scores_df, x = 'feature', y = 'bc', color = 'k', s = 3, ax=axes[0])

sns.boxplot(data=feature_scores_df, x = 'feature', y = 'spearman', color = 'white' ,width = .5, ax=axes[1])
sns.swarmplot(data=feature_scores_df, x = 'feature', y = 'spearman', color = 'k', s = 3, ax=axes[1])


plt.tight_layout()
plt.savefig('feature_scores.png', dpi=300)

# %%
taxonomy_scores[['k', 'p', 'c', 'o', 'f', 'g', 's']] = taxonomy_scores.column.str.split('|', expand=True)

# %%
plt.figure(figsize = (15, 5))
sns.boxplot(x = taxonomy_scores.g, y = taxonomy_scores.mape, fliersize=0, width = .5, color='white')
sns.swarmplot(x = taxonomy_scores.g, y = taxonomy_scores.mape, s=4)
plt.tick_params(axis='x', rotation=90)
plt.title('MAPE FOR DIFFEREN GENUS')
plt.tight_layout()
plt.savefig('taxonomy_mape_genus.png', dpi=300)

# %%
taxonomy_mean_df = taxonomy_val.mean().reset_index().rename({'index':'column', 0:'mean'},axis=1)
taxonomy_scores_df = pd.merge(taxonomy_mean_df, taxonomy_scores, on="column")

pathways_mean_df = pathways_val.mean().reset_index().rename({'index':'column', 0:'mean'},axis=1)
pathways_scores_df = pd.merge(pathways_mean_df, pathways_scores, on="column")


fig, axes = plt.subplots(1, 2, figsize = (10, 4))
sns.regplot(data = taxonomy_scores_df, y = np.log(taxonomy_scores_df['mean']), 
            x = 'spearman',
            ax=axes[0],
            line_kws = {'color':'red'}, 
            scatter_kws = {'edgecolor':'k', 'color':'white'})

sns.regplot(data = pathways_scores_df, y = np.log(pathways_scores_df['mean']), 
            x = 'spearman',
            ax=axes[1],
            line_kws = {'color':'red'}, 
            scatter_kws = {'edgecolor':'k', 'color':'white'})

axes[0].set_title('taxonomy mean vs corr')
axes[1].set_title('pathways mean vs corr')

plt.tight_layout()
plt.savefig('mean_vs_corr.png', dpi=300)

# %%
cooc_taxonomy_score = score_cooccurrence(t_decoded_df, taxonomy_val, 'taxonomy')
cooc_pathways_score = score_cooccurrence(p_decoded_df, pathways_val, 'pathways')

COOC_SCORES_DF = pd.concat([cooc_taxonomy_score, cooc_pathways_score], axis=0).reset_index(drop=True)

# %%
fig, axes = plt.subplots(1, 2, figsize = (7, 3))

sns.boxplot(data = COOC_SCORES_DF, x = 'data', y = 'mape', ax=axes[0], color= 'white')
sns.swarmplot(data = COOC_SCORES_DF, x = 'data', y = 'mape', ax=axes[0], color = 'black', edgecolor= 'black')

sns.boxplot(data = COOC_SCORES_DF, x = 'data', y = 'spearman_corr', ax=axes[1], color= 'white')
sns.swarmplot(data = COOC_SCORES_DF, x = 'data', y = 'spearman_corr', ax=axes[1], color = 'black', edgecolor= 'black')
plt.title('COOCURRENCE SCORES')
plt.tight_layout()
plt.savefig('cooc_score.png', dpi=300)

# %%
cooc_taxonomy_score[['k', 'p', 'c', 'o', 'f', 'g', 's']] = cooc_taxonomy_score.feature.str.split('|', expand=True)

# %%
plt.figure(figsize = (10, 5))
sns.boxplot(x = cooc_taxonomy_score.g, y = cooc_taxonomy_score.mape, fliersize=0, width = .5, color='white')
sns.swarmplot(x = cooc_taxonomy_score.g, y = cooc_taxonomy_score.mape, s=4)
plt.tick_params(axis='x', rotation=90)
plt.title('MAPE FOR DIFFEREN GENUS')
plt.tight_layout()
plt.savefig('coocmape_genus.png', dpi=300)
